# %% [markdown]
# <a href="https://colab.research.google.com/github/gujralvikas/hello-world/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(5):
  print ('hello AI', i)

a = 6
# Out:
# hello AI 0
# hello AI 1
# hello AI 2
# hello AI 3
# hello AI 4

# %%
# Defining a
a = 6
a
# Out:
# 6

# %%
a+2
# Out:
# 8

# %%
b = 'hello'
len(b)
# Out:
# 5

# %%
b + str(len(b))
# Out:
# 'hello5'

# %% [markdown]
# This section of the code is just for testing Python

# %%
num = int(input("Enter a number: "))

print(f"Multiplication Table for {num}:")
for i in range(1, 11):
   print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number: 5
# Multiplication Table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
def repeat (word, exclaim):
  """ To repeat the word multiple times"""

  temp = word + word + word
  if exclaim:
    temp = temp + '!!!'
  return temp

# %%
print (repeat('I love you', 1))
# Out:
# I love youI love youI love you!!!
